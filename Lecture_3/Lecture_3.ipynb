# %% [markdown]
# # Lecture 3

# %% [markdown]
# # Part A  Short Exercises (traditional programming exercises)

# %% [markdown]
# ## Exercise 1 — Clamp a Value
#
# Write:
#
# ```python
# clamp(value, lower, upper)
# ```
#
# The function should:
# - return `lower` if `value < lower`,
# - return `upper` if `value > upper`,
# - otherwise return `value`.
#
# Examples:
#
# ```python
# clamp(12, 0, 10)   # 10
# clamp(-3, 0, 10)   # 0
# clamp(7, 0, 10)    # 7
# ```
#
# **Main concept:** `if / elif / else`

# %%
def clamp(value, lower, upper):
    # TODO

# %% [markdown]
# ## Exercise 2 — Factorial
#
# For a positive integer:
#
# $$
# n! = 1 \cdot 2 \cdot 3 \cdots n
# $$
#
# Write:
#
# ```python
# factorial(n)
# ```
#
# using a `for` loop.
#
# Checks:
#
# $$
# 5! = 120
# $$
#
# $$
# 7! = 5040
# $$
#
# **Main concept:** `for` loop and accumulation

# %%
def factorial(n):
    # TODO

# %% [markdown]
# ## Exercise 3 — Greatest Common Divisor
#
# Write:
#
# ```python
# gcd(a, b)
# ```
#
# using Euclid's algorithm.
#
# Repeatedly perform:
#
# $$
# a,b \leftarrow b,\ a \bmod b
# $$
#
# until:
#
# $$
# b = 0
# $$
#
# Example:
#
# ```python
# gcd(48, 18)   # 6
# ```
#
# **Main concept:** `while`

# %%
def gcd(a, b):
    # TODO

# %% [markdown]
# ## Exercise 4 — First Divisor
#
# Write:
#
# ```python
# first_divisor(n)
# ```
#
# Search from `2` upward and stop when the first exact divisor is found.
#
# Examples:
#
# ```python
# first_divisor(15)   # 3
# first_divisor(49)   # 7
# first_divisor(17)   # 17
# ```
#
#
# **Main concept:** `break`

# %%
def first_divisor(n):
    # TODO

# %% [markdown]
# ## Exercise 5 — Sum While Skipping Multiples
#
# Write:
#
# ```python
# sum_except_multiples(n, divisor)
# ```
#
# Add the integers from `1` to `n`, but skip values divisible by `divisor`.
#
# Example:
#
# ```python
# sum_except_multiples(10, 3)
# ```
#
# should calculate:
#
# $$
# 1+2+4+5+7+8+10 = 37
# $$
#
# **Main concept:** `continue`

# %%
def sum_except_multiples(n, divisor):
    # TODO
    pass

# %% [markdown]
# ## Exercise 6 — Kinetic Energy
#
# The kinetic energy is:
#
# $$
# E_k = \frac{1}{2}mv^2
# $$
#
# Write:
#
# ```python
# kinetic_energy(mass, speed)
# ```
#
# Ask the user to enter the mass and speed, then pass them to the function.
#
# Example:
#
# $$
# m=10\ \mathrm{kg}, \qquad v=4\ \mathrm{m/s}
# $$
#
# gives:
#
# $$
# E_k=80\ \mathrm{J}
# $$
#
# **Main concepts:** parameters, `return`, `input()`

# %%
def kinetic_energy(mass, speed):
    # TODO

# TODO: Read mass and speed using input()
# TODO: Call the function
# TODO: Print the result

# %% [markdown]
# ## Exercise 7 — Local Variable
#
# Write:
#
# ```python
# circle_area(radius)
# ```
#
# using:
#
# $$
# A = \pi r^2
# $$
#
# Inside the function, store the result in a variable called:
#
# ```python
# area
# ```
#
# Return the result.
#
# After calling the function, try:
#
# ```python
# print(area)
# ```
#
# What happens, and why?
#
# **Main concept:** local variables

# %%
import math

def circle_area(radius):
    # TODO: Create a local variable called area
    # TODO: Return it

# TODO: Call the function
# Then try:
# print(area)

# %% [markdown]
# ## Exercise 8 — Global Counter
#
# Start with:
#
# ```python
# machine_cycles = 0
# ```
#
# Write:
#
# ```python
# register_cycle()
# ```
#
# Every call should increase the global counter by `1`.
#
# Call it three times and print the final value.
#
#
# **Main concept:** global variables and `global`

# %%
machine_cycles = 0

def register_cycle():
    # TODO

# TODO: Call three times
# TODO: Print machine_cycles

# %% [markdown]
# ## Exercise 9 — Minimum, Maximum, and Sum
#
# Ask the user to enter **three numbers**.
#
# Write:
#
# ```python
# number_summary(a, b, c)
# ```
#
# The function should determine:
# - minimum,
# - maximum,
# - sum.
#
# Requirements:
# - use `input()`,
# - convert inputs with `float()`,
# - use local variables,
# - use `if`,
# - do **not** use built-in `min()`, `max()`, or `sum()`.
#
# Example input:
#
# ```text
# 8
# 3
# 12
# ```
#
# Expected output:
#
# ```text
# Minimum = 3
# Maximum = 12
# Sum = 23
# ```
#
# **Main concepts:** `input()`, functions, local variables, `if`

# %%
number1 = float(input("Enter number 1: "))
number2 = float(input("Enter number 2: "))
number3 = float(input("Enter number 3: "))

def number_summary(a, b, c):
    # TODO

number_summary(number1, number2, number3)

# %% [markdown]
# ## Exercise 10 — Multiplication Grid
#
# Write:
#
# ```python
# multiplication_grid(rows, columns)
# ```
#
# Example:
#
# ```python
# multiplication_grid(3, 4)
# ```
#
# should print:
#
# ```text
# 1  2  3  4
# 2  4  6  8
# 3  6  9  12
# ```
#
# **Main concept:** nested loops

# %%
def multiplication_grid(rows, columns):
    # TODO: outer loop for rows
    # TODO: inner loop for columns

# %% [markdown]
# ## Exercise 11 — Bolt Positions
#
# A plate has rows and columns of bolt positions.
#
# Write:
#
# ```python
# bolt_positions(rows, columns)
# ```
#
# For:
#
# ```python
# bolt_positions(2, 3)
# ```
#
# print:
#
# ```text
# Row 1 Column 1
# Row 1 Column 2
# Row 1 Column 3
# Row 2 Column 1
# Row 2 Column 2
# Row 2 Column 3
# ```
#
# **Main concept:** nested loops and loop order

# %%
def bolt_positions(rows, columns):
    # TODO

# %% [markdown]
# # Part B — Predict the Output
#
# For each question:
#
# 1. Read the code.
# 2. Do not run it first.
# 3. Choose A, B, C, or D
# 4. Then run the code to check your answer

# %% [markdown]
# ## Question 1 — `if / elif / else`
#
# ```python
# x = 12
#
# if x < 5:
#     print("A")
# elif x < 10:
#     print("B")
# else:
#     print("C")
# ```
#
# **A.** `A`
# **B.** `B`
# **C.** `C`
# **D.** Nothing

# %% [markdown]
# ## Question 2 — `for`
#
# ```python
# total = 0
#
# for i in range(1, 5):
#     total = total + i
#
# print(total)
# ```
#
# **A.** `6`
# **B.** `10`
# **C.** `15`
# **D.** `5`

# %% [markdown]
# ```markdown
# ## Question 3 — `range`
#
# <pre>
# for i in range(2, 9, 2):
#     print(i)
# </pre>
#
# **Choose the correct output:**
#
# | A | B | C | D |
# |:--:|:--:|:--:|:--:|
# | 2<br>4<br>6<br>8 | 2<br>4<br>6<br>8<br>10 | 2<br>3<br>4<br>5<br>6<br>7<br>8 | 0<br>2<br>4<br>6<br>8 |

# %% [markdown]
# ## Question 4 — `while`
#
# ```python
# x = 1
#
# while x < 10:
#     x = x * 2
#
# print(x)
# ```
#
# **A.** `8`
# **B.** `10`
# **C.** `16`
# **D.** `20`

# %% [markdown]
# ## Question 5 — `break`
#
# ```python
# for i in range(1, 10):
#     if i == 4:
#         break
#     print(i)
# ```
#
# **A.**
# ```text
# 1
# 2
# 3
# ```
#
# **B.**
# ```text
# 1
# 2
# 3
# 4
# ```
#
# **C.**
# ```text
# 4
# ```
#
# **D.**
# ```text
# 1
# 2
# 3
# 5
# 6
# 7
# 8
# 9
# ```

# %% [markdown]
# ## Question 6 — `continue`
#
# ```python
# for i in range(1, 6):
#     if i == 3:
#         continue
#     print(i)
# ```
#
# **A.**
# ```text
# 1
# 2
# 3
# 4
# 5
# ```
#
# **B.**
# ```text
# 1
# 2
# ```
#
# **C.**
# ```text
# 1
# 2
# 4
# 5
# ```
#
# **D.**
# ```text
# 3
# ```

# %% [markdown]
# ## Question 7 — Function and `return`
#
# ```python
# def double(x):
#     return x * 2
#
# a = double(4)
# print(a + 1)
# ```
#
# **A.** `5`
# **B.** `8`
# **C.** `9`
# **D.** `16`

# %% [markdown]
# ## Question 8 — Parameters and Arguments
#
# ```python
# def subtract(a, b):
#     return a - b
#
# print(subtract(10, 3))
# ```
#
# **A.** `7`
# **B.** `-7`
# **C.** `13`
# **D.** `30`

# %% [markdown]
# ## Question 9 — Local Variable
#
# ```python
# def calculate():
#     result = 25
#     print(result)
#
# calculate()
# print(result)
# ```
#
# **A.** Prints `25` twice
# **B.** Prints `25`, then raises `NameError`
# **C.** Raises `NameError` before printing anything
# **D.** Prints `0`

# %% [markdown]
# ## Question 10 — Global Variable
#
# ```python
# counter = 2
#
# def increase():
#     global counter
#     counter = counter + 3
#
# increase()
# increase()
#
# print(counter)
# ```
#
# **A.** `5`
# **B.** `6`
# **C.** `8`
# **D.** `10`

# %% [markdown]
# ## Question 11 — Local and Global Variables
#
# ```python
# x = 10
#
# def show():
#     x = 4
#     print(x)
#
# show()
# print(x)
# ```
#
# **A.**
# ```text
# 4
# 4
# ```
#
# **B.**
# ```text
# 10
# 10
# ```
#
# **C.**
# ```text
# 4
# 10
# ```
#
# **D.**
# ```text
# 10
# 4
# ```

# %% [markdown]
# ## Question 12 — User Input
#
# Suppose the user enters `5`.
#
# ```python
# number = int(input("Enter a number: "))
#
# if number % 2 == 0:
#     print("Even")
# else:
#     print("Odd")
# ```
#
# **A.** `Even`
# **B.** `Odd`
# **C.** `5`
# **D.** Nothing

# %% [markdown]
# ## Question 13 — Input Conversion
#
# Suppose the user enters `6` and then `4`.
#
# ```python
# a = float(input("Enter a: "))
# b = float(input("Enter b: "))
#
# print(a + b)
# ```
#
# **A.** `64`
# **B.** `10`
# **C.** `10.0`
# **D.** `2.0`

# %% [markdown]
# ## Question 14 — Minimum Logic
#
# ```python
# a = 8
# b = 3
# c = 12
#
# minimum = a
#
# if b < minimum:
#     minimum = b
#
# if c < minimum:
#     minimum = c
#
# print(minimum)
# ```
#
# **A.** `3`
# **B.** `8`
# **C.** `12`
# **D.** `23`

# %% [markdown]
# ## Question 15 — Nested Loops
#
# ```python
# count = 0
#
# for row in range(3):
#     for column in range(2):
#         count = count + 1
#
# print(count)
# ```
#
# **A.** `2`
# **B.** `3`
# **C.** `5`
# **D.** `6`

# %% [markdown]
# ## Question 16 — Nested Loop Order
#
# ```python
# for i in range(1, 3):
#     for j in range(1, 3):
#         print(i, j)
# ```
#
# **A.**
# ```text
# 1 1
# 1 2
# 2 1
# 2 2
# ```
#
# **B.**
# ```text
# 1 1
# 2 1
# 1 2
# 2 2
# ```
#
# **C.**
# ```text
# 1 2
# 2 1
# ```
#
# **D.**
# ```text
# 1 1
# 2 2
# ```

# %% [markdown]
# ## Question 17 — `break` in a Nested Loop
#
# ```python
# for i in range(2):
#     for j in range(4):
#         if j == 2:
#             break
#         print(i, j)
# ```
#
# **A.**
# ```text
# 0 0
# 0 1
# ```
#
# **B.**
# ```text
# 0 0
# 0 1
# 1 0
# 1 1
# ```
#
# **C.**
# ```text
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# ```
#
# **D.**
# ```text
# 0 0
# 1 0
# ```

# %% [markdown]
# ## Question 18 — `continue` in a `while`
#
# ```python
# x = 0
# total = 0
#
# while x < 5:
#     x = x + 1
#
#     if x == 3:
#         continue
#
#     total = total + x
#
# print(total)
# ```
#
# **A.** `12`
# **B.** `15`
# **C.** `3`
# **D.** `9`

# %% [markdown]
# ## Question 19 — Function with a Condition
#
# ```python
# def check_temperature(t):
#     if t > 100:
#         return "High"
#     else:
#         return "Normal"
#
# print(check_temperature(100))
# ```
#
# **A.** `High`
# **B.** `Normal`
# **C.** `100`
# **D.** Nothing

# %% [markdown]
# ## Question 20 — Function + Loop + Condition
#
# ```python
# def count_even(n):
#     count = 0
#
#     for i in range(1, n + 1):
#         if i % 2 == 0:
#             count = count + 1
#
#     return count
#
# print(count_even(7))
# ```
#
# **A.** `2`
# **B.** `3`
# **C.** `4`
# **D.** `7`

# %% [markdown]
# ---
#
# # Final Check
#
# Make sure you can explain:
#
# - `for` vs `while`
# - `break` vs `continue`
# - parameter vs argument
# - local vs global variable
# - defining vs calling a function
# - `print` vs `return`
# - one loop vs nested loops
